# %%
import cv2

# %%
img2 = cv2.imread('Video 1.mp4')

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('kkk.jpg')

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-23af6c37b3d0> in <module>
# ----> 1 plt.imshow(img)
#
# AttributeError: module 'matplotlib' has no attribute 'imshow'

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pridictions = DeepFace.analyze(img,enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [01:37<00:00, 24.46s/it]

# %%
pridictions
# Out:
# {'emotion': {'angry': 7.054997581690259e-05,
#   'disgust': 1.032874689034303e-14,
#   'fear': 0.021969809313304722,
#   'happy': 99.97383952140808,
#   'sad': 4.670790758609655e-05,
#   'surprise': 0.0039437207306036726,
#   'neutral': 0.00012832914535465534},
#  'dominant_emotion': 'happy',
#  'region': {'x': 0, 'y': 0, 'w': 800, 'h': 1200},
#  'age': 40,
#  'gender': 'Woman',
#  'race': {'asian': 0.5468001309693016,
#   'indian': 1.796435220114615,
#   'black': 0.06514246537185793,
#   'white': 45.27850392800617,
#   'middle eastern': 12.53313720621314,
#   'latino hispanic': 39.77998373269841},
#  'dominant_race': 'white'}

# %%
pip install DeepFace
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import DeepFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-a9e3e907fc6e> in <module>
# ----> 1 import DeepFace
#
# ModuleNotFoundError: No module named 'DeepFace'

# %%
cap = cv2.VideoCapture('Video 1.mp4') # open a video file or camera
assert cap.isOpened() ####"file/camera could not be opened!"
while True:
   (success, img) = cap.read() # cap.read() always returns a tuple of two things
   if not success: break # you absolutely must check this
   cv2.imshow("Video", img)
    
   if cv2.waitKey(1) & 0xFF == ord('q'):
      breakcap = cv2.VideoCapture('Video 1.mp4') # open a video file or camera
assert cap.isOpened(), "file/camera could not be opened!"
while True:
   (success, img) = cap.read() # cap.read() always returns a tuple of two things
   if not success: break # you absolutely must check this
   cv2.imshow("Video", img)
   if cv2.waitKey(1) & 0xFF == ord('q'):
      break
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-24935cc7b7b2> in <module>
#       6    cv2.imshow("Video", img)
#       7    if cv2.waitKey(1) & 0xFF == ord('q'):
# ----> 8       breakcap = cv2.VideoCapture(...) # open a video file or camera
#       9 assert cap.isOpened(), "file/camera could not be opened!"
#      10 while True:
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'VideoCapture'
# > Overload resolution failed:
# >  - Can't convert object to 'str' for 'filename'
# >  - VideoCapture() missing required argument 'apiPreference' (pos 2)
# >  - Argument 'index' is required to be an integer
# >  - VideoCapture() missing required argument 'apiPreference' (pos 2)

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\avize /.deepface created
# Directory  C:\Users\avize /.deepface/weights created

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
facecascade2 = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default-Copy1.xml")

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
faces = facecascade2.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-43-832d52f6b19c> in <module>
#       1 gray = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# ----> 2 faces = facecascade2.detectMultiScale(gray,1.1,4)
#       3
#       4 for(x,y,w,h) in faces:
#       5   cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            pridictions['dominant_emotion'],
            (0,50),
            font,1,
            (0,255,0),
            2,
            cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
faces = face_cascade.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default-Copy1.xml")

# %%
cap = cv2.VideoCapture('Video 1.mp4') # open a video file or camera
assert cap.isOpened() ####"file/camera could not be opened!"
while True:
    success, img = cap.read() # cap.read() always returns a tuple of two things
    if not success: break # you absolutely must check this
    count = 0 

    
    result = DeepFace.analyze(img,actions=['emotions'])

    gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)

    face = faceCascade0.detectMultiScale(gray , 1,1,4)

    for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.putText(img,
            pridictions['dominant_emotion'],(0,50),font,1,(0,255,0),2,cv2.LINE_4)
   
    cv2.imshow("Video", img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        breakcap = cv2.VideoCapture('Video 1.mp4') # open a video file or camera
assert cap.isOpened(), "file/camera could not be opened!"
while True:
   (success, img) = cap.read() # cap.read() always returns a tuple of two things
   if not success: break # you absolutely must check this
   cv2.imshow("Video", img)
   if cv2.waitKey(1) & 0xFF == ord('q'):
      break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-bf49d4a5ac98> in <module>
#       7
#       8
# ----> 9     result = DeepFace.analyze(img,actions=['emotions'])
#      10
#      11     gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
#
# C:\ProgramData\Anaconda3\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     448                                 is_region_set = True
#     449                                 for i, parameter in enumerate(region_labels):
# --> 450                                         resp_obj["region"][parameter] = int(region[i]) #int cast is for the exception - object of type 'float32' is not JSON serializable
#     451
#     452                 #---------------------------------
#
# IndexError: list index out of range

# %%
facecascade2 = cv2.CascadeClassifier(cv2.data.haarcascades + "/content/haarcascade_licence_plate_rus_16stages.xml")

# %%
cap = cv2.VideoCapture('Video 1.mp4') # open a video file
if not cap.isOpened():
    cap = cv2.VideoCapture(img2)
if not cap.isOpened():
    print('fake')

while True :
    success, frame = cap.read()
    result = DeepFace.analyze(frame,enforce_detection=False)
    gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)

    face = haar_cascade.detectMultiScale(gray ,1.2,3,0,(0,0) )
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.putText(frame,
            pridictions['dominant_emotion'],(0,50),font,1,(0,255,0),2,cv2.LINE_4)
    cv2.line(frame, (0, 0), (511, 511), (255, 0, 0), 5)
    cv2.imshow('',frame)
    ######cv2.imshow(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.56it/s]

# %%
,actions=['emotions']

# %%
# !wget --no-check-certificate \
https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml \
-O haarcascade_frontalface_default.xml
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
haar_cascade = cv2.CascadeClassifier(cv2.samples.findFile
                                    (cv2.data.haarcascades+"haarcascade_frontalface_default.xml"))
